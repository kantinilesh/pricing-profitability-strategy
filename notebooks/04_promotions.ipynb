# %% [markdown]
# # Notebook 04: Promotion Effectiveness & Net Trade Spend ROI
# ## Campaign Archetype Profitability Evaluation
# Calculates incremental volume lift, net trade spend, manufacturer co-op funding offsets, and net incremental ROI.

# %%
import os
import pandas as pd
from src.analysis.promotions.promotion_effectiveness import main as run_promo_eff
from src.analysis.promotions.promotion_roi import main as run_promo_roi

run_promo_eff()
run_promo_roi()
