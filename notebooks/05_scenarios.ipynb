# %% [markdown]
# # Notebook 05: Strategic Scenario Engine & Sensitivity Simulator
# ## Strategic Alternatives Modeling (Scenarios A - G)
# Simulates strategic alternatives (Scenarios A through G) and 3-tier sensitivity analysis (Base, Upside, Downside).

# %%
import os
import pandas as pd
from src.analysis.scenarios.scenario_engine import main as run_scenarios
from src.analysis.scenarios.sensitivity_analysis import main as run_sensitivity

run_scenarios()
run_sensitivity()
