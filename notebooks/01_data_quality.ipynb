# %% [markdown]
# # Notebook 01: Data Quality Audit & Cleaning
# ## OmniRetail India Data Foundation
# This notebook executes automated data quality audits, imputes missing records, and validates transaction reconciliation math.

# %%
import os
import pandas as pd
from src.data.02_validate_data import main as validate_data
from src.data.03_clean_data import main as clean_data

print("--- Executing Data Quality Audit ---")
validate_data()
clean_data()
