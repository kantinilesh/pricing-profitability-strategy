# %% [markdown]
# # Notebook 03: Pricing Strategy & Price Elasticity Modeling
# ## Econometric Demand Response & Price Realization
# Fits Log-Log OLS regressions to estimate category price elasticity coefficients and evaluates price realization.

# %%
import os
import pandas as pd
from src.analysis.pricing.price_waterfall import main as run_waterfall
from src.analysis.pricing.elasticity import main as run_elasticity

run_waterfall()
run_elasticity()
