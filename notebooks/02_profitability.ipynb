# %% [markdown]
# # Notebook 02: Profitability Diagnosis & Price-Volume-Mix (PVM) Bridge
# ## OmniRetail India Margin Analysis
# Decomposes gross margin erosion, category profitability, and regional logistics cost-to-serve.

# %%
import os
import pandas as pd
from src.analysis.profitability.profitability_diagnosis import main as run_diagnosis
from src.analysis.profitability.profit_bridge import main as run_bridge

run_diagnosis()
run_bridge()
